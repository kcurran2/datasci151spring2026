# %% [markdown]
# Edit lecture notes
# <font size="10">
# Hello
# #Big text

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Additional notes here

# %%
print("Another python command")
# Out:
# Another python command
