# %%
#Loops
for i in range(n):
    # runs n times
for name in names:
    print(name)
for a, b in zip(list1, list2):
    print(a, b)

# Lists
lst = [1, 2, 3]
lst[0]  # first element
lst.append(4) #add elements

#Pandas basics
import pandas as pd

df = pd.read_csv("file.csv")

#Access rows
df.loc[i] #  explicit row and column labels (names) to select data.
df.iloc[i] #uses implicit numerical indices (positions), similar to standard Python list indexing, starting from 0.

#Create new columns
df["new_col"] = df["col1"] + df["col2"]

#filter data
df[df["age"] > 20]
